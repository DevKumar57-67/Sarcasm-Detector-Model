# %% [markdown]
# <a href="https://colab.research.google.com/github/DevKumar57-67/Sarcasm-Detector-Model/blob/main/Sarcasm_detector_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px

# %%
data= pd.read_csv("/content/test.csv")

# %%
data.head()
# Out:
#                                               tweets       class
# 0  no one ever predicted this was going to happen...  figurative
# 1  @Stooshie its as closely related as Andrews or...  figurative
# 2  I find it ironic when Vegans say they love foo...  figurative
# 3  Quick rt that throwing money vine I've not see...  figurative
# 4  yep, keep adding me to your #devops lists.... ...  figurative

# %%
data.tail()
# Out:
#                                                  tweets    class
# 8123  Why yes I will totally submit my photos to a s...  sarcasm
# 8124  Test on a Saturday! Thank you uni! #sarcasm @ ...  sarcasm
# 8125  Listening to @StephenKing's Misery isn't at al...  sarcasm
# 8126  @mmcpatt There you go being kind again #sarcas...  sarcasm
# 8127  I'm shocked that these refs in the tcu vs minn...  sarcasm

# %%
data.shape
# Out:
# (8128, 2)

# %%
data.describe()
# Out:
#                                                    tweets  class
# count                                                8126   8119
# unique                                               7993      4
# top     Wow! Look at all that surgery done! 😉😱 #ariana...  irony
# freq                                                    2   2111

# %%
data.sample()
# Out:
#                                                  tweets  class
# 3744  So after 3 years on the food committee the boa...  irony

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweets  8126 non-null   object
#  1   class   8119 non-null   object
# dtypes: object(2)
# memory usage: 127.1+ KB

# %%
data.isnull().sum()
# Out:
# tweets    2
# class     9
# dtype: int64

# %%
data.isnull()
# Out:
#       tweets  class
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 8123   False  False
# 8124   False  False
# 8125   False  False
# 8126   False  False
# 8127   False  False
#
# [8128 rows x 2 columns]

# %%
data['class'].value_counts()
# Out:
# class
# irony         2111
# sarcasm       2105
# figurative    2044
# regular       1859
# Name: count, dtype: int64

# %%
data['tweets'].value_counts()
# Out:
# tweets
# Wow! Look at all that surgery done! 😉😱 #arianagrande #sarcastic #omg #😍 #l4l #f4f https://t.co/rACcbP0hNK                                    2
# Mourinho: "Chelsea's rivals are trying to buy the premiere league." #EPL #Irony http://t.co/rR8bU0WMe3                                       2
# Never thought I'd see the day when #humpday and #JoeJackson would be trending topics on Twitter at the same time. #ironic #Viagra            2
# 'Good Job, Good Effort!' Dynamo!!! https://t.co/C1wnzmSczr #sarcasm                                                                          2
# @PANYNJ @PATHTrain I LOVE that the WTC station has nothing to indicate when the next train is coming.  Info like that is stupid! #sarcasm    2
#                                                                                                                                             ..
# ...

# %%
class TextCleaner:
    def __init__(self, text):
        self.text = text

    def clean_text(self):
        self.text = remove_html_tags(self.text)
        self.text = remove_urls(self.text)
        self.text = remove_non_alphanumeric(self.text)
        self.text = remove_extra_whitespace(self.text)
        return self.text

# Utility Functions
def remove_html_tags(text):
    clean_text = re.sub(r'<.*?>', '', text)
    return clean_text

def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

def remove_non_alphanumeric(text):
    return re.sub(r'[^A-Za-z0-9\s]', '', text)

def remove_extra_whitespace(text):
    return re.sub(r'\s+', ' ', text).strip()

# Example Usage
if __name__ == "__main__":
    sample_text = """
    <html>
        <body>
            Visit us at https://example.com or http://example.org for more info.
            Email us at info@example.com!
            Call us at +123-456-7890.
        </body>
    </html>
    """
    cleaner = TextCleaner(sample_text)
    clean_text = cleaner.clean_text()
    print(clean_text)
# Out:
# Visit us at or for more info Email us at infoexamplecom Call us at 1234567890

# %%
# Example Usage
if __name__ == "__main__":
    sample_text= """
Wow! Look at all that surgery done! 😉😱 #arianagrande #sarcastic #omg #😍 #l4l #f4f https://t.co/rACcbP0hNK                                    2
Mourinho: "Chelsea's rivals are trying to buy the premiere league." #EPL #Irony http://t.co/rR8bU0WMe3                                       2
    """
    cleaner = TextCleaner(sample_text)
    clean_text = cleaner.clean_text()
    print(clean_text)
# Out:
# Wow Look at all that surgery done arianagrande sarcastic omg l4l f4f 2 Mourinho Chelseas rivals are trying to buy the premiere league EPL Irony 2
